# %%
import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np
from itertools import combinations, groupby
from collections import Counter

# %%
orders = pd.read_csv('all_orders.csv', index_col = 0)
cluster_df = pd.read_csv('cluster_df')
products = pd.read_csv('products.csv')
aisles = pd.read_csv('aisles.csv')
departments = pd.read_csv('departments.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
orders = orders.sort_values(['order_id','product_id'])
orders
# Out:
#           order_id  product_id  add_to_cart_order  reordered  aisle_id  \
# 30264547         1       10246                  3          0        83
# 30264545         1       11109                  2          1       108
# 30264548         1       13176                  6          0        24
# 30264544         1       22035                  8          1        21
# 30264550         1       43633                  5          1        95
# ...            ...         ...                ...        ...       ...
# 23108244   3421083       21162                  3          0        92
# 23108238   3421083       24852                  9          1        24
# 23108247   3421083       35211                  5          0        92
# 23108242   3421083       39678                  6          1        74
# 23108246   3421083       45309                  2          0        92
#
#           department_id                 aisle    department  user_id  cluster
# 30264547              4      fresh vegetables       produce   112108        5
# 30264545             16  other creams cheeses    dairy eggs   112108        5
# 30264548              4          fresh fruits       produce   112108        5
# 30264544             16       packaged cheese    dairy eggs   112108        5
# 30264550             15   canned meat seafood  canned goods   112108        5
# ...                 ...                   ...           ...      ...      ...
# 23108244             18     baby food formula        babies    25247        5
# 23108238              4          fresh fruits       produce    25247        5
# 23108247             18     baby food formula        babies    25247        5
# 23108242             17       dish detergents     household    25247        5
# 23108246             18     baby food formula        babies    25247        5
#
# [33819106 rows x 10 columns]

# %%
# Returns frequency counts for items and item pairs
def freq(iterable):
    if type(iterable) == pd.core.series.Series:
        return iterable.value_counts().rename("freq")
    else: 
        return pd.Series(Counter(iterable)).rename("freq")

    
# Returns number of unique orders
def order_count(order_item):
    return len(set(order_item.index))


# Returns generator that yields item pairs, one at a time
def get_item_pairs(order_item):
    order_item = order_item.reset_index().to_numpy()
    for order_id, order_object in groupby(order_item, lambda x: x[0]):
        item_list = [item[1] for item in order_object]
              
        for item_pair in combinations(item_list, 2):
            yield item_pair
            

# Returns frequency and support associated with item
def merge_item_stats(item_pairs, item_stats):
    return (item_pairs
                .merge(item_stats.rename(columns={'freq': 'freqA', 'support': 'supportA'}), left_on='item_A', right_index=True)
                .merge(item_stats.rename(columns={'freq': 'freqB', 'support': 'supportB'}), left_on='item_B', right_index=True))


# Returns name associated with item
def merge_item_name(rules, item_name):
    columns = ['itemA','itemB','freqAB','supportAB','freqA','supportA','freqB','supportB', 
               'confidenceAtoB','confidenceBtoA','lift']
    rules = (rules
                .merge(item_name.rename(columns={'item_name': 'itemA'}), left_on='item_A', right_on='item_id')
                .merge(item_name.rename(columns={'item_name': 'itemB'}), left_on='item_B', right_on='item_id'))

# %%
def association_rules(order_item, min_support):

    print("Starting order_item: {:22d}".format(len(order_item)))


    # Calculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) 


    # Filter from order_item items below min support 
    qualifying_items       = item_stats[item_stats['support'] >= min_support].index
    order_item             = order_item[order_item.isin(qualifying_items)]

    print("Items with support >= {}: {:15d}".format(min_support, len(qualifying_items)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Filter from order_item orders with less than 2 items
    order_size             = freq(order_item.index)
    qualifying_orders      = order_size[order_size >= 2].index
    order_item             = order_item[order_item.index.isin(qualifying_orders)]

    print("Remaining orders with 2+ items: {:11d}".format(len(qualifying_orders)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Recalculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) 


    # Get item pairs generator
    item_pair_gen          = get_item_pairs(order_item)


    # Calculate item pair frequency and support
    item_pairs              = freq(item_pair_gen).to_frame("freqAB")
    item_pairs['supportAB'] = item_pairs['freqAB'] / len(qualifying_orders)

    print("Item pairs: {:31d}".format(len(item_pairs)))


    # Filter from item_pairs those below min support
    item_pairs              = item_pairs[item_pairs['supportAB'] >= min_support]

    print("Item pairs with support >= {}: {:10d}\n".format(min_support, len(item_pairs)))


    # Create table of association rules and compute relevant metrics
    item_pairs = item_pairs.reset_index().rename(columns={'level_0': 'item_A', 'level_1': 'item_B'})
    item_pairs = merge_item_stats(item_pairs, item_stats)
    
    item_pairs['confidenceAtoB'] = item_pairs['supportAB'] / item_pairs['supportA']
    item_pairs['confidenceBtoA'] = item_pairs['supportAB'] / item_pairs['supportB']
    item_pairs['lift']           = item_pairs['supportAB'] / (item_pairs['supportA'] * item_pairs['supportB'])
    
    
    # Return association rules sorted by lift in descending order
    return item_pairs.sort_values('lift', ascending=False)

# %%
# separate order data by cluster and transform into expected format of group association function

cluster_orders = {}
for x in range(0,6):
    i = orders[orders['cluster'] == x]
    i = i.set_index('order_id')['product_id'].rename('item_id')
    cluster_orders[x] = i

# %%
# run each cluster series through association rule function and obtain association rules at item level

group_association_rules_dic = {}
for x in range(0,6):
    group_association_rules_dic[x] = association_rules(cluster_orders[x],.0001)
# Out:
# Starting order_item:                5714445
# Items with support >= 0.0001:            7547
# Remaining order_item:               5433087
# Remaining orders with 2+ items:      518168
# Remaining order_item:               5414155
# Item pairs:                         5087275
# Item pairs with support >= 0.0001:      91877
#
# Starting order_item:                 219870
# Items with support >= 0.0001:            4796
# Remaining order_item:                204518
# Remaining orders with 2+ items:       37565
# Remaining order_item:                193295
# Item pairs:                          220291
# Item pairs with support >= 0.0001:      35858
#
# Starting order_item:               10128193
# Items with support >= 0.0001:           13288
# Remaining order_item:               9182459
# Remaining orders with 2+ items:      990115
# Remaining order_item:               9106863
# Item pairs:                        15985469
# Item pairs with support >= 0.0001:      28487
#
# Starting order_item:                 540699
# Items with support >= 0.0001:            1064
# Remaining order_item:                537610
# Remaining orders with 2+ items:      100123
# Remaining order_item:                520137
# Item pairs:                          151667
# Item pairs with support >= 0.0001:      24505
#
# Starting order_item:                1652006
# Items with support >= 0.0001:            6109
# Remaining order_item:               1548677
# Remaining orders with 2+ items:      216252
# Remaining order_item:               1526879
# Item pairs:                         1546900
# Item pairs with support >= 0.0001:      45185
#
# Starting order_item:               15563893
# Items with support >= 0.0001:           10335
# Remaining order_item:              14640901
# Remaining orders with 2+ items:     1281740
# Remaining order_item:              14601499
# Item pairs:                        14052510
# Item pairs with support >= 0.0001:      94763

# %%
# format item association rule dataframes and merge product names

for x in group_association_rules_dic:
    group_association_rules_dic[x] = group_association_rules_dic[x].merge(products[['product_id','product_name']]
               .rename(columns = {'product_id':'item_A','product_name':'product_name_A'}), on = 'item_A')
    group_association_rules_dic[x] = group_association_rules_dic[x].merge(products[['product_id','product_name']]
               .rename(columns = {'product_id':'item_B','product_name':'product_name_B'}), on = 'item_B')
    group_association_rules_dic[x] = group_association_rules_dic[x][['item_A','item_B','product_name_A',
                                                                    'product_name_B','freqAB','supportAB','freqA',
                                                                    'supportA','freqB','supportB','confidenceAtoB',
                                                                    'confidenceBtoA','lift']]

# %%
# example of association rule dataframe

x = group_association_rules_dic[5]
x.sort_values('lift', ascending = False)
# Out:
#        item_A  item_B                                     product_name_A  \
# 0       20153   46949            Eat Your Colors Purples Puree Baby Food
# 1       29671   38652                      Organic Bluephoria Yerba Mate
# 2        6583   38652            Oraganic Lemon Elation Yerba Mate Drink
# 5        6583   29671            Oraganic Lemon Elation Yerba Mate Drink
# 11       8833    9497  Smoothie Fruits, Squished, The Green One, Over...
# 6       11187   29671                             Revel Berry Yerba Mate
# 1925    41349   49570                 Dairy Free Greek Yogurt Strawberry
# 1927    43788   46352                Organic Pearfecto Level 1 Baby Food
# 1930    19097   47940                         Light Harvest Peach Yogurt
# 1932    11224   39739           Organic Cashew Nondairy Blueberry Yogurt
# 1926    36835   49570               Dairy Free Greek Yogurt Black Cherry
# 1935    19244   26488              Grassfed Whole Milk Strawberry Yogurt
# 1937    16466   40982                       Organic Amaze Mint Baby Food
# 3       11187   38652                             Revel Berry Yerba Mate
# 1941    27553   30388   Organic Blueberry Cream On Top Whole Milk Yogurt
# 1944    27402   33124     Healthy Kids Organic Vanilla Nutritional Shake
# 1940    16466   31657                       Organic Amaze Mint Baby Food
# 1946     7657   19513                                      Hair Shampoos
# 1947     1134   10401              The Red ONe: Squished Fruit Smoothies
# 3141    22416   41271  O'Soy Fruit on the Bottom Strawberry Organic S...
# 3146    29126   36361   Organic Strawberry Chia Lowfat 2% Cottage Cheese
# 1928    40982   46352                   Organic Lavenberry Puree Level 2
# 12       1134    9497              The Red ONe: Squished Fruit Smoothies
# 1936    19244   21931              Grassfed Whole Milk Strawberry Yogurt
# 3147    13005   26899                         Grow Well Muscle Baby Food
# 3148     1337    7922                     Yogurt, Sheep Milk, Strawberry
# 1929    31657   46352               Organic Basil Babe Level 1 Baby Food
# 7       14366   29671                             Enlighten Mint Organic
# 6397     9618   43445                  Wild Berry Sparkling Energy Water
# 6396    31657   43788               Organic Basil Babe Level 1 Baby Food
# ...       ...     ...                                                ...
# 1146    21195   24852                     Organic Extra Virgin Olive Oil
# 2216    19003   21137                                             Celery
# 3918    38400   47209                Asparation/Broccolini/Baby Broccoli
# 8015    11777   27966                                    Red Raspberries
# 77913   21903   28993                               Organic Baby Spinach
# 54873    8277   29487                           Apple Honeycrisp Organic
# 6744    13166   27845               Organic Milk Reduced Fat, 2% Milkfat
# 3141   1153.292093
# 3146   1126.826223
# 1928   1112.062651
# 12     1104.623879
# 1936   1102.696499
# 3147   1101.690068
# 3148   1087.015619
# 1929   1070.293196
# 7      1052.897593
# 6397   1037.792630
# 6396    996.699326
# ...            ...
# 1146      0.341326
# 2216      0.341011
# 3918      0.337446
# 8015      0.332228
# 77913     0.329718
# 54873     0.327069
# 6744      0.324855
# 84111     0.311792
# 12184     0.302245
# 11037     0.302244
# 65780     0.296477
# 64550     0.296387
# 6946      0.287759
# 3586      0.283368
# 42360     0.274826
# 6750      0.265381
# 57334     0.258806
# 5779      0.256797
# 40321     0.160682
# 38331     0.152361
# 26233     0.141188
# 11050     0.123727
# 3687      0.110945
# 27117     0.090600
# 3762      0.080726
# 2333      0.080073
# 15682     0.079351
# 13552     0.057778
# 9815      0.053803
# 961       0.017604
#
# [94763 rows x 13 columns]

# %%
# separate order data by cluster and transform into expected format of group association function at aisle level

cluster_aisle_orders = {}
for x in range(0,6):
    i = orders[orders['cluster'] == x]
    i = i.groupby(['order_id','aisle_id'])['product_id'].count().reset_index().set_index('order_id')['aisle_id'].rename('item_id')
    cluster_aisle_orders[x] = i

# %%
orders.groupby(['order_id','aisle_id'])['product_id'].count().reset_index().set_index('order_id')['aisle_id'].rename('item_id')
# Out:
# order_id
# 1           21
# 1           24
# 1           83
# 1           95
# 1          108
#           ...
# 3421083     52
# 3421083     74
# 3421083     78
# 3421083     92
# 3421083    117
# Name: item_id, Length: 24329222, dtype: int64

# %%
orders[orders['cluster'] == 5]['order_id'].nunique()
# Out:
# 1325895

# %%
# run association function at aisle level

group_aisle_association_rules_dic = {}
for x in range(0,6):
    group_aisle_association_rules_dic[x] = association_rules(cluster_aisle_orders[x],.0001)
# Out:
# Starting order_item:                3744330
# Items with support >= 0.0001:             134
# Remaining order_item:               3744330
# Remaining orders with 2+ items:      518732
# Remaining order_item:               3723763
# Item pairs:                            8841
# Item pairs with support >= 0.0001:       6251
#
# Starting order_item:                 142874
# Items with support >= 0.0001:             134
# Remaining order_item:                142874
# Remaining orders with 2+ items:       34461
# Remaining order_item:                128100
# Item pairs:                            6636
# Item pairs with support >= 0.0001:       4178
#
# Starting order_item:                7661793
# Items with support >= 0.0001:             134
# Remaining order_item:               7661793
# Remaining orders with 2+ items:      989145
# Remaining order_item:               7576779
# Item pairs:                            8908
# Item pairs with support >= 0.0001:       8209
#
# Starting order_item:                 417170
# Items with support >= 0.0001:             118
# Remaining order_item:                417128
# Remaining orders with 2+ items:       97719
# Remaining order_item:                397081
# Item pairs:                            5725
# Item pairs with support >= 0.0001:       3384
#
# Starting order_item:                1122653
# Items with support >= 0.0001:             134
# Remaining order_item:               1122653
# Remaining orders with 2+ items:      210744
# Remaining order_item:               1093673
# Item pairs:                            8523
# Item pairs with support >= 0.0001:       5299
#
# Starting order_item:               11240402
# Items with support >= 0.0001:             134
# Remaining order_item:              11240402
# Remaining orders with 2+ items:     1285934
# Remaining order_item:              11200441
# Item pairs:                            8906
# Item pairs with support >= 0.0001:       7577

# %%
# reformat cluster aisle assocation dataframes

for x in group_aisle_association_rules_dic:
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].merge(aisles[['aisle_id','aisle']]
               .rename(columns = {'aisle_id':'item_A','aisle':'aisle_name_A'}), on = 'item_A')
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].merge(aisles[['aisle_id','aisle']]
               .rename(columns = {'aisle_id':'item_B','aisle':'aisle_name_B'}), on = 'item_B')
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x][['item_A','item_B','aisle_name_A',
                                                                    'aisle_name_B','freqAB','supportAB','freqA',
                                                                    'supportA','freqB','supportB','confidenceAtoB',
                                                                    'confidenceBtoA','lift']]
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].rename(columns = {'item_A':'aisle_A','item_B':'aisle_B'})

# %%
x = group_aisle_association_rules_dic[5].sort_values('lift',ascending = False)
x.sort_values('lift',ascending = False)
# Out:
#       aisle_A  aisle_B         aisle_name_A                aisle_name_B  \
# 0          28       62            red wines                 white wines
# 38        124      134              spirits  specialty wines champagnes
# 39         62      134          white wines  specialty wines champagnes
# 40         27      134        beers coolers  specialty wines champagnes
# 37         28      134            red wines  specialty wines champagnes
# ...       ...      ...                  ...                         ...
# 150       120      124               yogurt                     spirits
# 146        91      124      soy lactosefree                     spirits
# 5166       27       92        beers coolers           baby food formula
# 5165       28       92            red wines           baby food formula
# 102         3      124  energy granola bars                     spirits
#
#       freqAB  supportAB   freqA  supportA  freqB  supportB  confidenceAtoB  \
# 0       1770   0.001376    7042  0.005476   6505  0.005059        0.251349
# 38       365   0.000284    5163  0.004015   2209  0.001718        0.070695
# 39       439   0.000341    6505  0.005059   2209  0.001718        0.067487
# 40       363   0.000282    5534  0.004303   2209  0.001718        0.065595
# 37       426   0.000331    7042  0.005476   2209  0.001718        0.060494
# ...      ...        ...     ...       ...    ...       ...             ...
# 150      686   0.000533  438578  0.341058   5163  0.004015        0.001564
# 146      413   0.000321  274969  0.213828   5163  0.004015        0.001502
# 5166     140   0.000109    5534  0.004303  90776  0.070591        0.025298
# 5165     159   0.000124    7042  0.005476  90776  0.070591        0.022579
# 102      138   0.000107  126956  0.098727   5163  0.004015        0.001087
#
#       confidenceBtoA       lift
# 0           0.272098  49.687669
# 38          0.165233  41.154156
# 39          0.198732  39.286214
# 40          0.164328  38.184792
# 37          0.192847  35.215718
# ...              ...        ...
# 150         0.132868   0.389577
# 146         0.079992   0.374096
# 5166        0.001542   0.358374
# 5165        0.001752   0.319852
# 102         0.026729   0.270734
#
# [7577 rows x 13 columns]

# %%
cluster_df['cluster'].value_counts() / cluster_df['cluster'].value_counts().sum()
# Out:
# 2    0.356114
# 5    0.353462
# 0    0.161244
# 4    0.072029
# 3    0.038519
# 1    0.018632
# Name: cluster, dtype: float64

# %%
for x in group_association_rules_dic:
    group_association_rules_dic[x].to_csv('group'+str(x)+'_item_rules.csv')

# %%
for x in group_aisle_association_rules_dic:
    group_aisle_association_rules_dic[x].to_csv('group'+str(x)+'_aisle_rules.csv')
